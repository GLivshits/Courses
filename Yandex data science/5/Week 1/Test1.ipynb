# %%
import pandas as pd
import numpy as np
import calendar
import re
from matplotlib import pyplot as plt
from statsmodels.tsa.stattools import adfuller

# %%
data = pd.read_csv('monthly-milk-production.csv', engine = 'python', sep = ';')

# %%
data
# Out:
#           month  milk
# 0    01.01.1962   589
# 1    01.02.1962   561
# 2    01.03.1962   640
# 3    01.04.1962   656
# 4    01.05.1962   727
# ..          ...   ...
# 163  01.08.1975   858
# 164  01.09.1975   817
# 165  01.10.1975   827
# 166  01.11.1975   797
# 167  01.12.1975   843
#
# [168 rows x 2 columns]

# %%
arr = []

for i in range(0, data.shape[0]):

    arr.append(data['milk'].iloc[i]/calendar.monthrange(int(data['month'].iloc[i].split('.')[2]), int(data['month'].iloc[i].split('.')[1]))[1])

# %%
arr = np.array(arr)

# %%
plt.plot(np.arange(0, len(arr), 1) , diff2)

# %%
data['milk'] = arr

# %%
diff1 = data['milk'] - data['milk'].shift(1)

# %%
adfuller(diff2.dropna())
# Out:
# (-5.481326334796932,
#  2.2808455518036712e-06,
#  11,
#  143,
#  {'1%': -3.4769274060112707,
#   '5%': -2.8819726324025625,
#   '10%': -2.577665408088415},
#  -20.90513750989237)

# %%
diff2 = diff1 - diff1.shift(12)

# %%
import statsmodels.api as sm
sm.graphics.tsa.plot_acf(diff2.dropna().values.squeeze(), lags=50)

# %%
import statsmodels.api as sm
sm.graphics.tsa.plot_pacf(diff2.dropna().values.squeeze(), lags=50)
